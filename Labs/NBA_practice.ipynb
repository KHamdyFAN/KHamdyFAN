# %% [markdown]
# <a href="https://colab.research.google.com/github/KHamdyFAN/KHamdyFAN/blob/main/NBA_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nba.csv')

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
print(df.isna().sum())
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
updated_df = df.dropna()

# %%
updated_df.to_csv('/content/cleaned_data.txt', sep=',')

# %%
with open('cleaned_data.txt') as f:
    while True:
        data = f.read(1024)  # Reading 1024 bytes at a time
        if not data:
            break
        print(data)
# Out:
# ,Name,Team,Number,Position,Age,Height,Weight,College,Salary
# 0,Avery Bradley,Boston Celtics,0.0,PG,25.0,6-2,180.0,Texas,7730337.0
# 1,Jae Crowder,Boston Celtics,99.0,SF,25.0,6-6,235.0,Marquette,6796117.0
# 3,R.J. Hunter,Boston Celtics,28.0,SG,22.0,6-5,185.0,Georgia State,1148640.0
# 6,Jordan Mickey,Boston Celtics,55.0,PF,21.0,6-8,235.0,LSU,1170960.0
# 7,Kelly Olynyk,Boston Celtics,41.0,C,25.0,7-0,238.0,Gonzaga,2165160.0
# 8,Terry Rozier,Boston Celtics,12.0,PG,22.0,6-2,190.0,Louisville,1824360.0
# 9,Marcus Smart,Boston Celtics,36.0,PG,22.0,6-4,220.0,Oklahoma State,3431040.0
# 10,Jared Sullinger,Boston Celtics,7.0,C,24.0,6-9,260.0,Ohio State,2569260.0
# 11,Isaiah Thomas,Boston Celtics,4.0,PG,27.0,5-9,185.0,Washington,6912869.0
# 12,Evan Turner,Boston Celtics,11.0,SG,27.0,6-7,220.0,Ohio State,3425510.0
# 13,James Young,Boston Celtics,13.0,SG,20.0,6-6,215.0,Kentucky,1749840.0
# 14,Tyler Zeller,Boston Celtics,44.0,C,26.0,7-0,253.0,North Carolina,2616975.0
# ...

# %%
groupby_df = df.groupby('Team')['Salary'].mean()

# %%
groupby_df.head()
# Out:
# Team
# Atlanta Hawks        4.860197e+06
# Boston Celtics       4.181505e+06
# Brooklyn Nets        3.501898e+06
# Charlotte Hornets    5.222728e+06
# Chicago Bulls        5.785559e+06
# Name: Salary, dtype: float64

# %%
groupby_age = df.groupby('Position')['Age'].mean()

# %%
groupby_age.head()
# Out:
# Position
# C     27.371795
# PF    27.160000
# PG    26.847826
# SF    26.858824
# SG    26.539216
# Name: Age, dtype: float64

# %%
middle = len(updated_df) / 2

# %%
df_first_half = updated_df.iloc[:int(middle)]

# %%
df_first_half.tail()
# Out:
#                 Name             Team  Number Position   Age Height  Weight  \
# 215      Tyler Ennis  Milwaukee Bucks    11.0       PG  21.0    6-3   194.0
# 216      John Henson  Milwaukee Bucks    31.0       PF  25.0   6-11   229.0
# 218        O.J. Mayo  Milwaukee Bucks     3.0       SG  28.0    6-5   210.0
# 219  Khris Middleton  Milwaukee Bucks    22.0       SG  24.0    6-8   234.0
# 220      Greg Monroe  Milwaukee Bucks    15.0        C  26.0   6-11   265.0
#
#             College      Salary
# 215        Syracuse   1662360.0
# 216  North Carolina   2943221.0
# 218             USC   8000000.0
# 219       Texas A&M  14700000.0
# 220      Georgetown  16407500.0

# %%
df_second_half = updated_df.iloc[int(middle):]

# %%
df_second_half.head()
# Out:
#                     Name             Team  Number Position   Age Height  \
# 221          Steve Novak  Milwaukee Bucks     6.0       SF  32.0   6-10
# 222  Johnny O'Bryant III  Milwaukee Bucks    77.0       PF  23.0    6-9
# 223        Jabari Parker  Milwaukee Bucks    12.0       PF  21.0    6-8
# 224        Miles Plumlee  Milwaukee Bucks    18.0        C  27.0   6-11
# 225      Greivis Vasquez  Milwaukee Bucks    21.0       PG  29.0    6-6
#
#      Weight    College     Salary
# 221   225.0  Marquette   295327.0
# 222   257.0        LSU   845059.0
# 223   250.0       Duke  5152440.0
# 224   249.0       Duke  2109294.0
# 225   217.0   Maryland  6600000.0

# %%
concatenated_df = pd.concat([df_first_half, df_second_half])

# %%
concatenated_df.sort_values(by='Salary', ascending=False).head(10)
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 33     Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
# 339         Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 100         Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164       Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# 349        Dwyane Wade             Miami Heat     3.0       SG  34.0    6-4
# 174         Kevin Love    Cleveland Cavaliers     0.0       PF  27.0   6-10
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 98      DeAndre Jordan   Los Angeles Clippers     6.0        C  27.0   6-11
# 23         Brook Lopez          Brooklyn Nets    11.0        C  28.0    7-0
#
#      Weight       College      Salary
# 33    240.0      Syracuse  22875000.0
# 339   235.0  Georgia Tech  22192730.0
# ...

# %%
print(concatenated_df.isna().sum())
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
age_bins = pd.cut(df['Age'], bins=[20, 25, 30, 35],
labels=['Young', 'Middle-aged', 'Senior'])
print(age_bins)
# Out:
# 0            Young
# 1            Young
# 2      Middle-aged
# 3            Young
# 4      Middle-aged
#           ...
# 453    Middle-aged
# 454          Young
# 455    Middle-aged
# 456    Middle-aged
# 457            NaN
# Name: Age, Length: 458, dtype: category
# Categories (3, object): ['Young' < 'Middle-aged' < 'Senior']
